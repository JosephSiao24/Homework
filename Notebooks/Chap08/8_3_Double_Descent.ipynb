# %% [markdown]
# <a href="https://colab.research.google.com/github/JosephSiao24/Homework/blob/main/Notebooks/Chap08/8_3_Double_Descent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 8.3: Double Descent**
#
# This notebook investigates double descent as described in section 8.4 of the book.
#
# It uses the MNIST-1D database which can be found at https://github.com/greydanus/mnist1d
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TODO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# !pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /tmp/pip-req-build-j47o_yv0
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /tmp/pip-req-build-j47o_yv0
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.32.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (3.10.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (1.16.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (4.59.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2025.8.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.17.0)
# Building wheels for collected packages: mnist1d
#   Building wheel for mnist1d (pyproject.toml) ... done
#   Created wheel for mnist1d: filename=mnist1d-0.0.2.post16-py3-none-any.whl size=14665 sha256=c4ced1cdc9f7bab118b4c4c2e773def88d869508fdd131fcbc48f4fb3f73702b
#   Stored in directory: /tmp/pip-ephem-wheel-cache-7gei4j02/wheels/18/40/b6/29381fee9b4c80fdbc304d52bb065a7286bbcca5ca2b8737c0
# Successfully built mnist1d
# Installing collected packages: mnist1d
# Successfully installed mnist1d-0.0.2.post16

# %%
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import numpy as np
import matplotlib.pyplot as plt
import mnist1d
import random
random.seed(0)

# Try attaching to GPU -- Use "Change Runtime Type to change to GPUT"
DEVICE = str(torch.device('cuda' if torch.cuda.is_available() else 'cpu'))
print('Using:', DEVICE)
# Out:
# Using: cuda

# %%
args = mnist1d.data.get_dataset_args()
args.num_samples = 8000
args.train_split = 0.5
args.corr_noise_scale = 0.25
args.iid_noise_scale=2e-2
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=True)

# Add 15% noise to training labels
for c_y in range(len(data['y'])):
    random_number = random.random()
    if random_number < 0.15 :
        random_int = int(random.random() * 10)
        data['y'][c_y] = random_int

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Dimensionality of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 4000
# Dimensionality of each example: 40

# %%
# Initialize the parameters with He initialization
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# Return an initialized model with two hidden layers and n_hidden hidden units at each
def get_model(n_hidden):

  D_i = 40    # Input dimensions
  D_k = n_hidden   # Hidden dimensions
  D_o = 10    # Output dimensions

  # Define a model with two hidden layers
  # And ReLU activations between them
  model = nn.Sequential(
  nn.Linear(D_i, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_o))

  # Call the function you just defined
  model.apply(weights_init)

  # Return the model
  return model ;

# %%
def fit_model(model, data, n_epoch):

  # choose cross entropy loss function (equation 5.24)
  loss_function = torch.nn.CrossEntropyLoss()
  # construct SGD optimizer and initialize learning rate and momentum
  # optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
  optimizer = torch.optim.SGD(model.parameters(), lr = 0.01, momentum=0.9)


  x_train = torch.tensor(data['x'].astype('float32'))
  y_train = torch.tensor(data['y'].transpose().astype('long'))
  x_test= torch.tensor(data['x_test'].astype('float32'))
  y_test = torch.tensor(data['y_test'].astype('long'))

  # load the data into a class that creates the batches
  data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

  for epoch in range(n_epoch):
    # loop over batches
    for i, batch in enumerate(data_loader):
      # retrieve inputs and labels for this batch
      x_batch, y_batch = batch
      # zero the parameter gradients
      optimizer.zero_grad()
      # forward pass -- calculate model output
      pred = model(x_batch)
      # compute the loss
      loss = loss_function(pred, y_batch)
      # backward pass
      loss.backward()
      # SGD update
      optimizer.step()

    # Run whole dataset to get statistics -- normally wouldn't do this
    pred_train = model(x_train)
    pred_test = model(x_test)
    _, predicted_train_class = torch.max(pred_train.data, 1)
    _, predicted_test_class = torch.max(pred_test.data, 1)
    errors_train = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
    errors_test= 100 - 100 * (predicted_test_class == y_test).float().sum() / len(y_test)
    losses_train = loss_function(pred_train, y_train).item()
    losses_test= loss_function(pred_test, y_test).item()
    if epoch%100 ==0 :
      print(f'Epoch {epoch:5d}, train loss {losses_train:.6f}, train error {errors_train:3.2f},  test loss {losses_test:.6f}, test error {errors_test:3.2f}')

  return errors_train, errors_test

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

# %% [markdown]
# The following code produces the double descent curve by training the model with different numbers of hidden units and plotting the test error.
#
# TODO:
#
# *Before* you run the code, and considering that there are 4000 training examples predict:<br>
#
# 1.    At what capacity do you think the training error will become zero?4000
# 2.   At what capacity do you expect the first minima of the double descent curve to appear?4001
# 3. At what capacity do you expect the maximum of the double descent curve to appear?8000

# %%
# This code will take a while (~30 mins on GPU) to run!  Go and make a cup of coffee!

hidden_variables = np.array([2,4,6,8,10,14,18,22,26,30,35,40,45,50,55,60,70,80,90,100,120,140,160,180,200,250,300,400]) ;

errors_train_all = np.zeros_like(hidden_variables)
errors_test_all = np.zeros_like(hidden_variables)
total_weights_all = np.zeros_like(hidden_variables)

# loop over the dataset n_epoch times
n_epoch = 1000

# For each hidden variable size
for c_hidden in range(len(hidden_variables)):
    print(f'Training model with {hidden_variables[c_hidden]:3d} hidden variables')
    # Get a model
    model = get_model(hidden_variables[c_hidden]) ;
    # Count and store number of weights
    total_weights_all[c_hidden] = count_parameters(model)
    # Train the model
    errors_train, errors_test = fit_model(model, data, n_epoch)
    # Store the results
    errors_train_all[c_hidden] = errors_train
    errors_test_all[c_hidden]= errors_test
# Out:
# Training model with   2 hidden variables
# Epoch     0, train loss 2.303884, train error 89.55,  test loss 2.304919, test error 90.03
# Epoch   100, train loss 1.915863, train error 72.15,  test loss 1.762049, test error 70.28
# Epoch   200, train loss 1.892737, train error 70.78,  test loss 1.725076, test error 67.75
# Epoch   300, train loss 1.865437, train error 68.70,  test loss 1.705643, test error 66.82
# Epoch   400, train loss 1.868289, train error 68.35,  test loss 1.711914, test error 66.28
# Epoch   500, train loss 1.863363, train error 69.53,  test loss 1.706516, test error 66.25
# Epoch   600, train loss 1.870861, train error 68.60,  test loss 1.710286, test error 67.62
# Epoch   700, train loss 1.861638, train error 68.35,  test loss 1.705413, test error 66.47
# Epoch   800, train loss 1.861538, train error 68.22,  test loss 1.711081, test error 66.43
# Epoch   900, train loss 1.862796, train error 68.47,  test loss 1.708096, test error 66.10
# Training model with   4 hidden variables
# Epoch     0, train loss 2.298489, train error 89.72,  test loss 2.293583, test error 88.32
# Epoch   100, train loss 1.824491, train error 69.18,  test loss 1.672731, test error 67.30
# Epoch   200, train loss 1.785195, train error 66.60,  test loss 1.615160, test error 63.33
# Epoch   300, train loss 1.769610, train error 66.05,  test loss 1.601186, test error 63.30
# Epoch   400, train loss 1.756637, train error 66.05,  test loss 1.610291, test error 63.03
# Epoch   500, train loss 1.747585, train error 65.60,  test loss 1.605944, test error 62.92
# Epoch   600, train loss 1.749106, train error 65.72,  test loss 1.605517, test error 63.33
# Epoch   700, train loss 1.743122, train error 65.38,  test loss 1.613694, test error 63.78
# Epoch   800, train loss 1.742097, train error 65.47,  test loss 1.613639, test error 63.47
# Epoch   900, train loss 1.741853, train error 64.80,  test loss 1.614993, test error 63.25
# Training model with   6 hidden variables
# Epoch     0, train loss 2.292104, train error 87.85,  test loss 2.278760, test error 87.03
# Epoch   100, train loss 1.701706, train error 61.45,  test loss 1.529736, test error 59.03
# Epoch   200, train loss 1.628237, train error 58.45,  test loss 1.446880, test error 55.53
# Epoch   300, train loss 1.607715, train error 57.45,  test loss 1.441362, test error 55.65
# Epoch   400, train loss 1.605087, train error 57.83,  test loss 1.444155, test error 56.38
# Epoch   500, train loss 1.597870, train error 57.33,  test loss 1.450269, test error 56.38
# Epoch   600, train loss 1.591625, train error 56.67,  test loss 1.445243, test error 55.83
# Epoch   700, train loss 1.591108, train error 56.92,  test loss 1.449213, test error 55.95
# Epoch   800, train loss 1.585400, train error 56.62,  test loss 1.439347, test error 55.42
# Epoch   900, train loss 1.583753, train error 56.33,  test loss 1.437401, test error 55.38
# Training model with   8 hidden variables
# Epoch     0, train loss 2.149642, train error 80.35,  test loss 2.122472, test error 79.50
# Epoch   100, train loss 1.561097, train error 54.22,  test loss 1.392666, test error 52.08
# Epoch   200, train loss 1.504276, train error 51.72,  test loss 1.349428, test error 49.58
# Epoch   300, train loss 1.485557, train error 50.62,  test loss 1.334241, test error 49.62
# Epoch   400, train loss 1.466773, train error 50.03,  test loss 1.318433, test error 48.75
# Epoch   500, train loss 1.460019, train error 49.12,  test loss 1.311064, test error 48.33
# Epoch   600, train loss 1.446272, train error 48.30,  test loss 1.309295, test error 48.60
# Epoch   700, train loss 1.451748, train error 48.33,  test loss 1.328537, test error 49.35
# Epoch   800, train loss 1.442934, train error 48.20,  test loss 1.324055, test error 48.62
# Epoch   900, train loss 1.438742, train error 48.47,  test loss 1.334082, test error 48.65
# Training model with  10 hidden variables
# Epoch     0, train loss 2.254810, train error 85.00,  test loss 2.248995, test error 84.75
# Epoch   100, train loss 1.556133, train error 53.38,  test loss 1.381650, test error 52.38
# Epoch   200, train loss 1.504613, train error 51.50,  test loss 1.350355, test error 51.40
# Epoch   300, train loss 1.487810, train error 50.60,  test loss 1.341063, test error 51.00
# Epoch   400, train loss 1.463787, train error 49.88,  test loss 1.331412, test error 50.15
# Epoch   500, train loss 1.447072, train error 49.45,  test loss 1.329255, test error 50.22
# Epoch   600, train loss 1.435990, train error 48.95,  test loss 1.334391, test error 50.60
# Epoch   700, train loss 1.419388, train error 47.35,  test loss 1.307319, test error 49.25
# Epoch   800, train loss 1.408934, train error 47.55,  test loss 1.290408, test error 48.12
# Epoch   900, train loss 1.398624, train error 47.50,  test loss 1.285508, test error 47.22
# Training model with  14 hidden variables
# Epoch     0, train loss 2.248716, train error 83.62,  test loss 2.246687, test error 84.10
# Epoch   100, train loss 1.406035, train error 46.83,  test loss 1.257343, test error 46.58
# Epoch   200, train loss 1.325698, train error 43.17,  test loss 1.227280, test error 45.30
# Epoch   300, train loss 1.292153, train error 42.33,  test loss 1.246362, test error 46.25
# Epoch   400, train loss 1.274814, train error 41.72,  test loss 1.263541, test error 46.55
# Epoch   500, train loss 1.259775, train error 41.35,  test loss 1.279784, test error 46.00
# Epoch   600, train loss 1.249797, train error 41.22,  test loss 1.289161, test error 46.88
# Epoch   700, train loss 1.249551, train error 41.65,  test loss 1.304185, test error 46.70
# Epoch   800, train loss 1.240492, train error 40.97,  test loss 1.317838, test error 47.55
# Epoch   900, train loss 1.235583, train error 40.97,  test loss 1.341186, test error 47.53
# Training model with  18 hidden variables
# Epoch     0, train loss 2.196052, train error 81.22,  test loss 2.143883, test error 80.05
# Epoch   100, train loss 1.347111, train error 45.85,  test loss 1.342143, test error 50.53
# Epoch   200, train loss 1.268699, train error 43.12,  test loss 1.375139, test error 50.60
# Epoch   300, train loss 1.221953, train error 41.95,  test loss 1.392121, test error 50.65
# Epoch   400, train loss 1.196796, train error 40.08,  test loss 1.402527, test error 49.95
# Epoch   500, train loss 1.185868, train error 40.53,  test loss 1.457961, test error 50.83
# Epoch   600, train loss 1.167038, train error 40.20,  test loss 1.470269, test error 51.20
# Epoch   700, train loss 1.156046, train error 39.72,  test loss 1.479800, test error 51.28
# Epoch   800, train loss 1.148426, train error 39.95,  test loss 1.509129, test error 51.83
# Epoch   900, train loss 1.131699, train error 39.10,  test loss 1.551312, test error 52.53
# Training model with  22 hidden variables
# Epoch     0, train loss 2.179951, train error 81.00,  test loss 2.146638, test error 79.93
# Epoch   100, train loss 1.241064, train error 39.85,  test loss 1.232071, test error 45.97
# Epoch   200, train loss 1.116637, train error 36.22,  test loss 1.257919, test error 45.33
# Epoch   300, train loss 1.073772, train error 35.57,  test loss 1.341591, test error 46.72
# Epoch   400, train loss 1.040608, train error 34.07,  test loss 1.377218, test error 48.15
# Epoch   500, train loss 1.035129, train error 34.07,  test loss 1.421625, test error 47.70
# Epoch   600, train loss 0.998372, train error 33.15,  test loss 1.457507, test error 47.60
# Epoch   700, train loss 0.987363, train error 32.70,  test loss 1.488130, test error 48.30
# Epoch   800, train loss 1.001651, train error 33.82,  test loss 1.522131, test error 48.97
# Epoch   900, train loss 0.965286, train error 32.03,  test loss 1.536033, test error 49.38
# Training model with  26 hidden variables
# Epoch     0, train loss 2.198093, train error 79.95,  test loss 2.176919, test error 79.57
# Epoch   100, train loss 1.236804, train error 40.55,  test loss 1.366443, test error 51.53
# Epoch   200, train loss 1.084528, train error 36.90,  test loss 1.444973, test error 52.33
# Epoch   300, train loss 1.010536, train error 34.50,  test loss 1.542654, test error 52.60
# Epoch   400, train loss 0.956143, train error 32.47,  test loss 1.674018, test error 53.20
# Epoch   500, train loss 0.923767, train error 32.38,  test loss 1.778886, test error 54.15
# Epoch   600, train loss 0.882834, train error 29.57,  test loss 1.876589, test error 54.42
# Epoch   700, train loss 0.874598, train error 30.55,  test loss 1.973028, test error 54.85
# Epoch   800, train loss 0.853073, train error 29.53,  test loss 2.066963, test error 55.10
# Epoch   900, train loss 0.833722, train error 28.97,  test loss 2.135754, test error 55.03
# Training model with  30 hidden variables
# Epoch     0, train loss 2.154442, train error 80.47,  test loss 2.111869, test error 80.00
# Epoch   100, train loss 1.132527, train error 36.47,  test loss 1.472859, test error 53.40
# Epoch   200, train loss 0.950400, train error 31.55,  test loss 1.675826, test error 54.05
# Epoch   300, train loss 0.863687, train error 30.10,  test loss 1.854892, test error 54.72
# Epoch   400, train loss 0.811741, train error 27.40,  test loss 2.017464, test error 54.40
# Epoch   500, train loss 0.751103, train error 25.22,  test loss 2.170858, test error 54.67
# Epoch   600, train loss 0.740816, train error 25.43,  test loss 2.296838, test error 55.35
# Epoch   700, train loss 0.724328, train error 24.57,  test loss 2.474609, test error 55.83
# Epoch   800, train loss 0.696312, train error 23.85,  test loss 2.604889, test error 56.62
# Epoch   900, train loss 0.671715, train error 23.22,  test loss 2.774637, test error 56.55
# Training model with  35 hidden variables
# Epoch     0, train loss 2.102878, train error 77.93,  test loss 2.055914, test error 77.85
# Epoch   100, train loss 1.010481, train error 32.65,  test loss 1.349845, test error 47.55
# Epoch   200, train loss 0.774961, train error 25.20,  test loss 1.662735, test error 50.25
# Epoch   300, train loss 0.658132, train error 21.82,  test loss 2.042682, test error 53.65
# Epoch   400, train loss 0.574887, train error 18.47,  test loss 2.288729, test error 52.67
# Epoch   500, train loss 0.548315, train error 17.80,  test loss 2.597551, test error 53.62
# Epoch   600, train loss 0.504520, train error 16.72,  test loss 2.876131, test error 54.78
# Epoch   700, train loss 0.485712, train error 15.72,  test loss 3.149195, test error 55.05
# Epoch   800, train loss 0.462066, train error 16.10,  test loss 3.338367, test error 55.72
# Epoch   900, train loss 0.482325, train error 16.47,  test loss 3.715782, test error 57.92
# Training model with  40 hidden variables
# Epoch     0, train loss 2.099364, train error 78.57,  test loss 2.036866, test error 76.85
# Epoch   100, train loss 0.986369, train error 33.15,  test loss 1.455336, test error 51.45
# Epoch   200, train loss 0.710703, train error 22.97,  test loss 1.923929, test error 54.97
# Epoch   300, train loss 0.573754, train error 19.57,  test loss 2.414674, test error 55.45
# Epoch   400, train loss 0.474922, train error 16.15,  test loss 2.987909, test error 57.08
# Epoch   500, train loss 0.395438, train error 13.22,  test loss 3.680317, test error 57.78
# Epoch   600, train loss 0.359256, train error 12.03,  test loss 4.153424, test error 56.25
# Epoch   700, train loss 0.319594, train error 10.97,  test loss 4.711025, test error 57.20
# Epoch   800, train loss 0.274341, train error 8.95,  test loss 5.275015, test error 57.45
# Epoch   900, train loss 0.290851, train error 10.30,  test loss 5.798968, test error 57.90
# Training model with  45 hidden variables
# Epoch     0, train loss 2.054831, train error 76.78,  test loss 1.989645, test error 76.75
# Epoch   100, train loss 0.840673, train error 27.43,  test loss 1.444160, test error 48.92
# Epoch   200, train loss 0.529351, train error 18.28,  test loss 2.103823, test error 51.92
# Epoch   300, train loss 0.321214, train error 9.57,  test loss 3.097829, test error 53.30
# Epoch   400, train loss 0.236840, train error 7.95,  test loss 4.352426, test error 54.47
# Epoch   500, train loss 0.201476, train error 7.10,  test loss 5.549197, test error 55.70
# Epoch   600, train loss 0.219806, train error 7.78,  test loss 6.929999, test error 55.75
# Epoch   700, train loss 0.187008, train error 6.60,  test loss 7.719707, test error 55.53
# Epoch   800, train loss 0.081579, train error 2.60,  test loss 8.471239, test error 55.25
# Epoch   900, train loss 0.005552, train error 0.00,  test loss 9.198409, test error 55.67
# Training model with  50 hidden variables
# Epoch     0, train loss 2.115869, train error 79.60,  test loss 2.100666, test error 79.45
# Epoch   100, train loss 0.683163, train error 21.18,  test loss 1.637297, test error 51.20
# Epoch   200, train loss 0.309857, train error 9.75,  test loss 2.811095, test error 53.20
# Epoch   300, train loss 0.174253, train error 5.03,  test loss 4.535408, test error 55.40
# Epoch   400, train loss 0.025653, train error 0.00,  test loss 5.959454, test error 55.67
# Epoch   500, train loss 0.012052, train error 0.00,  test loss 6.835292, test error 56.50
# Epoch   600, train loss 0.007746, train error 0.00,  test loss 7.448485, test error 56.60
# Epoch   700, train loss 0.005643, train error 0.00,  test loss 7.897312, test error 56.55
# Epoch   800, train loss 0.004359, train error 0.00,  test loss 8.247314, test error 56.12
# Epoch   900, train loss 0.003549, train error 0.00,  test loss 8.553558, test error 56.22
# Training model with  55 hidden variables
# Epoch     0, train loss 2.078907, train error 77.43,  test loss 2.040560, test error 77.20
# Epoch   100, train loss 0.630135, train error 19.00,  test loss 1.657930, test error 50.85
# Epoch   200, train loss 0.212470, train error 4.88,  test loss 3.082926, test error 54.65
# Epoch   300, train loss 0.037434, train error 0.00,  test loss 4.736751, test error 55.80
# Epoch   400, train loss 0.014616, train error 0.00,  test loss 5.720572, test error 56.03
# Epoch   500, train loss 0.008302, train error 0.00,  test loss 6.322686, test error 56.58
# Epoch   600, train loss 0.005718, train error 0.00,  test loss 6.758185, test error 56.42
# Epoch   700, train loss 0.004296, train error 0.00,  test loss 7.093575, test error 56.62
# Epoch   800, train loss 0.003407, train error 0.00,  test loss 7.368425, test error 56.53
# Epoch   900, train loss 0.002789, train error 0.00,  test loss 7.595689, test error 56.58
# Training model with  60 hidden variables
# Epoch     0, train loss 2.064149, train error 75.88,  test loss 2.010349, test error 75.12
# Epoch   100, train loss 0.537954, train error 16.75,  test loss 1.684480, test error 50.05
# Epoch   200, train loss 0.105209, train error 0.93,  test loss 3.225646, test error 52.53
# Epoch   300, train loss 0.019418, train error 0.00,  test loss 4.540015, test error 53.28
# Epoch   400, train loss 0.009481, train error 0.00,  test loss 5.186460, test error 53.45
# Epoch   500, train loss 0.005992, train error 0.00,  test loss 5.621969, test error 53.47
# Epoch   600, train loss 0.004291, train error 0.00,  test loss 5.945435, test error 53.45
# Epoch   700, train loss 0.003264, train error 0.00,  test loss 6.202826, test error 53.33
# Epoch   800, train loss 0.002632, train error 0.00,  test loss 6.419115, test error 53.42
# Epoch   900, train loss 0.002180, train error 0.00,  test loss 6.600240, test error 53.40
# Training model with  70 hidden variables
# Epoch     0, train loss 2.092048, train error 76.47,  test loss 2.050559, test error 75.72
# Epoch   100, train loss 0.365869, train error 8.53,  test loss 1.853765, test error 50.12
# Epoch   200, train loss 0.033673, train error 0.00,  test loss 3.487013, test error 52.17
# Epoch   300, train loss 0.011180, train error 0.00,  test loss 4.266874, test error 52.35
# Epoch   400, train loss 0.006183, train error 0.00,  test loss 4.696514, test error 52.65
# Epoch   500, train loss 0.004162, train error 0.00,  test loss 4.996223, test error 52.58
# Epoch   600, train loss 0.003066, train error 0.00,  test loss 5.226735, test error 52.58
# Epoch   700, train loss 0.002408, train error 0.00,  test loss 5.411376, test error 52.83
# Epoch   800, train loss 0.001964, train error 0.00,  test loss 5.569614, test error 52.78
# Epoch   900, train loss 0.001649, train error 0.00,  test loss 5.702634, test error 52.80
# Training model with  80 hidden variables
# Epoch     0, train loss 2.048275, train error 77.10,  test loss 2.003869, test error 76.45
# Epoch   100, train loss 0.236867, train error 4.18,  test loss 2.018303, test error 51.17
# Epoch   200, train loss 0.021416, train error 0.00,  test loss 3.391211, test error 52.53
# Epoch   300, train loss 0.008467, train error 0.00,  test loss 3.967270, test error 52.80
# Epoch   400, train loss 0.004961, train error 0.00,  test loss 4.304018, test error 52.78
# Epoch   500, train loss 0.003420, train error 0.00,  test loss 4.541667, test error 52.90
# Epoch   600, train loss 0.002556, train error 0.00,  test loss 4.728596, test error 53.08
# Epoch   700, train loss 0.002026, train error 0.00,  test loss 4.879024, test error 53.15
# Epoch   800, train loss 0.001663, train error 0.00,  test loss 5.005427, test error 53.17
# Epoch   900, train loss 0.001404, train error 0.00,  test loss 5.114395, test error 53.17
# Training model with  90 hidden variables
# Epoch     0, train loss 1.982182, train error 73.97,  test loss 1.931631, test error 74.22
# Epoch   100, train loss 0.144604, train error 1.05,  test loss 2.230838, test error 52.67
# Epoch   200, train loss 0.015089, train error 0.00,  test loss 3.371355, test error 53.42
# Epoch   300, train loss 0.006555, train error 0.00,  test loss 3.824759, test error 53.38
# Epoch   400, train loss 0.004014, train error 0.00,  test loss 4.105764, test error 53.28
# Epoch   500, train loss 0.002807, train error 0.00,  test loss 4.306683, test error 53.55
# Epoch   600, train loss 0.002134, train error 0.00,  test loss 4.464212, test error 53.75
# Epoch   700, train loss 0.001701, train error 0.00,  test loss 4.592358, test error 53.60
# Epoch   800, train loss 0.001407, train error 0.00,  test loss 4.700497, test error 53.65
# Epoch   900, train loss 0.001194, train error 0.00,  test loss 4.794657, test error 53.67
# Training model with 100 hidden variables
# Epoch     0, train loss 2.013260, train error 74.20,  test loss 1.970248, test error 75.57
# Epoch   100, train loss 0.090533, train error 0.12,  test loss 2.241726, test error 50.38
# Epoch   200, train loss 0.012489, train error 0.00,  test loss 3.117025, test error 50.58
# Epoch   300, train loss 0.005765, train error 0.00,  test loss 3.490529, test error 50.85
# Epoch   400, train loss 0.003597, train error 0.00,  test loss 3.724164, test error 51.08
# Epoch   500, train loss 0.002550, train error 0.00,  test loss 3.895847, test error 50.72
# Epoch   600, train loss 0.001953, train error 0.00,  test loss 4.029402, test error 50.95
# Epoch   700, train loss 0.001567, train error 0.00,  test loss 4.139365, test error 50.95
# Epoch   800, train loss 0.001301, train error 0.00,  test loss 4.233918, test error 50.92
# Epoch   900, train loss 0.001108, train error 0.00,  test loss 4.315071, test error 50.88
# Training model with 120 hidden variables
# Epoch     0, train loss 2.016690, train error 76.10,  test loss 1.972409, test error 75.70
# Epoch   100, train loss 0.052135, train error 0.00,  test loss 2.227191, test error 50.25
# Epoch   200, train loss 0.009683, train error 0.00,  test loss 2.861188, test error 50.53
# Epoch   300, train loss 0.004755, train error 0.00,  test loss 3.150556, test error 50.72
# Epoch   400, train loss 0.003028, train error 0.00,  test loss 3.332422, test error 50.83
# Epoch   500, train loss 0.002178, train error 0.00,  test loss 3.467190, test error 50.88
# Epoch   600, train loss 0.001682, train error 0.00,  test loss 3.572999, test error 50.90
# Epoch   700, train loss 0.001360, train error 0.00,  test loss 3.662053, test error 50.83
# Epoch   800, train loss 0.001134, train error 0.00,  test loss 3.737245, test error 50.83
# Epoch   900, train loss 0.000969, train error 0.00,  test loss 3.802129, test error 50.78
# Training model with 140 hidden variables
# Epoch     0, train loss 1.950730, train error 72.00,  test loss 1.873921, test error 71.75
# Epoch   100, train loss 0.035328, train error 0.00,  test loss 2.136043, test error 49.62
# Epoch   200, train loss 0.007936, train error 0.00,  test loss 2.602148, test error 49.33
# Epoch   300, train loss 0.004081, train error 0.00,  test loss 2.825713, test error 49.25
# Epoch   400, train loss 0.002656, train error 0.00,  test loss 2.970195, test error 49.33
# Epoch   500, train loss 0.001937, train error 0.00,  test loss 3.078547, test error 49.45
# Epoch   600, train loss 0.001503, train error 0.00,  test loss 3.162937, test error 49.53
# Epoch   700, train loss 0.001221, train error 0.00,  test loss 3.234456, test error 49.55
# Epoch   800, train loss 0.001023, train error 0.00,  test loss 3.295193, test error 49.65
# Epoch   900, train loss 0.000876, train error 0.00,  test loss 3.348413, test error 49.65
# Training model with 160 hidden variables
# Epoch     0, train loss 1.947487, train error 71.57,  test loss 1.877788, test error 72.28
# Epoch   100, train loss 0.027547, train error 0.00,  test loss 2.144712, test error 49.30
# Epoch   200, train loss 0.007122, train error 0.00,  test loss 2.553099, test error 49.35
# Epoch   300, train loss 0.003741, train error 0.00,  test loss 2.753902, test error 49.22
# Epoch   400, train loss 0.002468, train error 0.00,  test loss 2.889342, test error 49.17
# Epoch   500, train loss 0.001807, train error 0.00,  test loss 2.988680, test error 49.17
# Epoch   600, train loss 0.001412, train error 0.00,  test loss 3.068815, test error 49.10
# Epoch   700, train loss 0.001151, train error 0.00,  test loss 3.134996, test error 49.05
# Epoch   800, train loss 0.000966, train error 0.00,  test loss 3.192164, test error 49.08
# Epoch   900, train loss 0.000830, train error 0.00,  test loss 3.242137, test error 49.08
# Training model with 180 hidden variables
# Epoch     0, train loss 1.924560, train error 71.22,  test loss 1.849882, test error 71.43
# Epoch   100, train loss 0.024815, train error 0.00,  test loss 2.074185, test error 48.78
# Epoch   200, train loss 0.006654, train error 0.00,  test loss 2.434637, test error 48.92
# Epoch   300, train loss 0.003548, train error 0.00,  test loss 2.614853, test error 49.05
# Epoch   400, train loss 0.002343, train error 0.00,  test loss 2.733935, test error 49.22
# Epoch   500, train loss 0.001723, train error 0.00,  test loss 2.824598, test error 49.22
# Epoch   600, train loss 0.001349, train error 0.00,  test loss 2.896847, test error 49.25
# Epoch   700, train loss 0.001101, train error 0.00,  test loss 2.956710, test error 49.17
# Epoch   800, train loss 0.000925, train error 0.00,  test loss 3.008410, test error 49.12
# Epoch   900, train loss 0.000795, train error 0.00,  test loss 3.053637, test error 49.05
# Training model with 200 hidden variables
# Epoch     0, train loss 1.960437, train error 71.93,  test loss 1.900148, test error 74.53
# Epoch   100, train loss 0.021671, train error 0.00,  test loss 2.049758, test error 47.92
# Epoch   200, train loss 0.006192, train error 0.00,  test loss 2.374533, test error 47.80
# Epoch   300, train loss 0.003365, train error 0.00,  test loss 2.541370, test error 47.97
# Epoch   400, train loss 0.002234, train error 0.00,  test loss 2.650495, test error 47.95
# Epoch   500, train loss 0.001650, train error 0.00,  test loss 2.733696, test error 47.83
# Epoch   600, train loss 0.001294, train error 0.00,  test loss 2.800159, test error 47.75
# Epoch   700, train loss 0.001058, train error 0.00,  test loss 2.856412, test error 47.75
# Epoch   800, train loss 0.000891, train error 0.00,  test loss 2.904206, test error 47.72
# Epoch   900, train loss 0.000767, train error 0.00,  test loss 2.946298, test error 47.70
# Training model with 250 hidden variables
# Epoch     0, train loss 1.908707, train error 69.12,  test loss 1.840091, test error 71.72
# Epoch   100, train loss 0.016987, train error 0.00,  test loss 1.929024, test error 47.12
# Epoch   200, train loss 0.005320, train error 0.00,  test loss 2.187180, test error 47.15
# Epoch   300, train loss 0.002964, train error 0.00,  test loss 2.323395, test error 47.22
# Epoch   400, train loss 0.002004, train error 0.00,  test loss 2.418289, test error 47.22
# Epoch   500, train loss 0.001491, train error 0.00,  test loss 2.489186, test error 47.12
# Epoch   600, train loss 0.001177, train error 0.00,  test loss 2.547152, test error 47.15
# Epoch   700, train loss 0.000966, train error 0.00,  test loss 2.595023, test error 47.28
# Epoch   800, train loss 0.000816, train error 0.00,  test loss 2.636015, test error 47.15
# Epoch   900, train loss 0.000704, train error 0.00,  test loss 2.672510, test error 47.25
# Training model with 300 hidden variables
# Epoch     0, train loss 1.869763, train error 67.10,  test loss 1.803357, test error 69.68
# Epoch   100, train loss 0.014671, train error 0.00,  test loss 1.896135, test error 47.10
# Epoch   200, train loss 0.004861, train error 0.00,  test loss 2.119206, test error 46.50
# Epoch   300, train loss 0.002750, train error 0.00,  test loss 2.240991, test error 46.25
# Epoch   400, train loss 0.001871, train error 0.00,  test loss 2.324094, test error 46.38
# Epoch   500, train loss 0.001400, train error 0.00,  test loss 2.387793, test error 46.33
# Epoch   600, train loss 0.001108, train error 0.00,  test loss 2.439119, test error 46.30
# Epoch   700, train loss 0.000912, train error 0.00,  test loss 2.482061, test error 46.33
# Epoch   800, train loss 0.000772, train error 0.00,  test loss 2.518867, test error 46.33
# Epoch   900, train loss 0.000667, train error 0.00,  test loss 2.551687, test error 46.42
# Training model with 400 hidden variables
# Epoch     0, train loss 1.872185, train error 67.45,  test loss 1.826949, test error 70.97
# Epoch   100, train loss 0.011515, train error 0.00,  test loss 1.739949, test error 46.35
# Epoch   200, train loss 0.004130, train error 0.00,  test loss 1.904518, test error 46.28
# Epoch   300, train loss 0.002392, train error 0.00,  test loss 1.997427, test error 46.28
# Epoch   400, train loss 0.001649, train error 0.00,  test loss 2.061076, test error 46.10
# Epoch   500, train loss 0.001243, train error 0.00,  test loss 2.111212, test error 46.20
# Epoch   600, train loss 0.000990, train error 0.00,  test loss 2.151066, test error 45.97
# Epoch   700, train loss 0.000818, train error 0.00,  test loss 2.184962, test error 45.97
# Epoch   800, train loss 0.000694, train error 0.00,  test loss 2.214080, test error 45.83
# Epoch   900, train loss 0.000602, train error 0.00,  test loss 2.239558, test error 45.85

# %%
import matplotlib.pyplot as plt
import numpy as np

# Assuming data['y'] is available and contains the training examples
num_training_examples = len(data['y'])

# Find the index where total_weights_all is closest to num_training_examples
closest_index = np.argmin(np.abs(np.array(total_weights_all) - num_training_examples))

# Get the corresponding value of hidden variables
hidden_variable_at_num_training_examples = hidden_variables[closest_index]

# Plot the results
fig, ax = plt.subplots()
ax.plot(hidden_variables, errors_train_all, 'r-', label='train')
ax.plot(hidden_variables, errors_test_all, 'b-', label='test')

# Add a vertical line at the point where total weights equal the number of training examples
ax.axvline(x=hidden_variable_at_num_training_examples, color='g', linestyle='--', label='N(weights) = N(train)')

ax.set_ylim(0, 100)
ax.set_xlabel('No. hidden variables')
ax.set_ylabel('Error')
ax.legend()
plt.show()

#double descent 出現在參數量接近dimensions附近但因爲一般來説深度學習的參數量往往遠多於資料集因此它可能不被重視
