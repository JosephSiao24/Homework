# %% [markdown]
# <a href="https://colab.research.google.com/github/JosephSiao24/Homework/blob/main/Notebooks/Chap08/8_1_MNIST_1D_Performance.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 8.1: MNIST_1D_Performance**
#
# This notebook runs a simple neural network on the MNIST1D dataset as in figure 8.2a. It uses code from https://github.com/greydanus/mnist1d to generate the data.
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TODO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# %pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /tmp/pip-req-build-2slmm4vr
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /tmp/pip-req-build-2slmm4vr
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.32.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (3.10.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (1.16.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (4.59.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2025.8.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.17.0)
# Building wheels for collected packages: mnist1d
#   Building wheel for mnist1d (pyproject.toml) ... done
#   Created wheel for mnist1d: filename=mnist1d-0.0.2.post16-py3-none-any.whl size=14665 sha256=6e66629634dacd03f379c0c6495e7cef7200ac7e0030709fea6bfb3caf3cdf4d
#   Stored in directory: /tmp/pip-ephem-wheel-cache-2yqlyysl/wheels/18/40/b6/29381fee9b4c80fdbc304d52bb065a7286bbcca5ca2b8737c0
# Successfully built mnist1d
# Installing collected packages: mnist1d
# Successfully installed mnist1d-0.0.2.post16

# %%
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import numpy as np
import matplotlib.pyplot as plt
import mnist1d

# %% [markdown]
# Let's generate a training and test dataset using the MNIST1D code.  The dataset gets saved as a .pkl file so it doesn't have to be regenerated each time.

# %%
args = mnist1d.data.get_dataset_args()
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=False)

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Length of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 1000
# Length of each example: 40

# %%
D_i = 40    # Input dimensions
D_k = 200  # Hidden dimensions
D_k1 = 40
D_o = 10    # Output dimensions
# TODO:
# Define a model with two hidden layers of size 100
# And ReLU activations between them
# Replace this line (see Figure 7.8 of book for help):
model = torch.nn.Sequential(torch.nn.Linear(D_i, D_k),
                torch.nn.ReLU(),
                torch.nn.Linear(D_k, D_k),
                torch.nn.ReLU(),
                torch.nn.Linear(D_k, D_o));


def weights_init(layer_in):
  # TODO:
  # Initialize the parameters with He initialization
  # Replace this line (see figure 7.8 of book for help)
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_normal_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)


# Call the function you just defined
model.apply(weights_init)
# Out:
# Sequential(
#   (0): Linear(in_features=40, out_features=200, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=200, out_features=200, bias=True)
#   (3): ReLU()
#   (4): Linear(in_features=200, out_features=10, bias=True)
# )

# %%
# choose cross entropy loss function (equation 5.24)
loss_function = torch.nn.CrossEntropyLoss()
# construct SGD optimizer and initialize learning rate and momentum
optimizer = torch.optim.SGD(model.parameters(), lr = 0.06, momentum=0.9)
# object that decreases learning rate by half every 10 epochs
scheduler = StepLR(optimizer, step_size=10, gamma=0.5)
x_train = torch.tensor(data['x'].astype('float32'))
y_train = torch.tensor(data['y'].transpose().astype('int64'))
x_test= torch.tensor(data['x_test'].astype('float32'))
y_test = torch.tensor(data['y_test'].astype('int64'))

# load the data into a class that creates the batches
data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=50, shuffle=True, worker_init_fn=np.random.seed(1))

# Initialize model weights
model.apply(weights_init)

# loop over the dataset n_epoch times
n_epoch = 50
# store the loss and the % correct at each epoch
losses_train = np.zeros((n_epoch))
errors_train = np.zeros((n_epoch))
losses_test = np.zeros((n_epoch))
errors_test = np.zeros((n_epoch))

for epoch in range(n_epoch):
  # loop over batches
  for i, batch in enumerate(data_loader):
    # retrieve inputs and labels for this batch
    x_batch, y_batch = batch
    # zero the parameter gradients
    optimizer.zero_grad()
    # forward pass -- calculate model output
    pred = model(x_batch)
    # compute the loss
    loss = loss_function(pred, y_batch)
    # backward pass
    loss.backward()
    # SGD update
    optimizer.step()

  # Run whole dataset to get statistics -- normally wouldn't do this
  pred_train = model(x_train)
  pred_test = model(x_test)
  _, predicted_train_class = torch.max(pred_train.data, 1)
  _, predicted_test_class = torch.max(pred_test.data, 1)
  errors_train[epoch] = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
  errors_test[epoch]= 100 - 100 * (predicted_test_class == y_test).float().sum() / len(y_test)
  losses_train[epoch] = loss_function(pred_train, y_train).item()
  losses_test[epoch]= loss_function(pred_test, y_test).item()
  print(f'Epoch {epoch:5d}, train loss {losses_train[epoch]:.6f}, train error {errors_train[epoch]:3.2f},  test loss {losses_test[epoch]:.6f}, test error {errors_test[epoch]:3.2f}')

  # tell scheduler to consider updating learning rate
  scheduler.step()
# Out:
# Epoch     0, train loss 1.365761, train error 50.03,  test loss 1.503011, test error 57.80
# Epoch     1, train loss 1.018688, train error 35.90,  test loss 1.249996, test error 48.30
# Epoch     2, train loss 0.813518, train error 28.35,  test loss 1.133647, test error 45.20
# Epoch     3, train loss 0.703668, train error 24.97,  test loss 1.135656, test error 42.40
# Epoch     4, train loss 0.539967, train error 18.97,  test loss 1.094923, test error 39.70
# Epoch     5, train loss 0.411652, train error 13.18,  test loss 1.017712, test error 36.70
# Epoch     6, train loss 0.311773, train error 9.43,  test loss 1.011467, test error 34.40
# Epoch     7, train loss 0.270362, train error 9.15,  test loss 1.066668, test error 35.60
# Epoch     8, train loss 0.243084, train error 7.78,  test loss 1.119082, test error 33.60
# Epoch     9, train loss 0.179515, train error 5.85,  test loss 1.125326, test error 34.30
# Epoch    10, train loss 0.056412, train error 0.57,  test loss 0.995045, test error 31.10
# Epoch    11, train loss 0.028804, train error 0.00,  test loss 1.028123, test error 30.40
# Epoch    12, train loss 0.020430, train error 0.00,  test loss 1.058546, test error 30.10
# Epoch    13, train loss 0.016132, train error 0.00,  test loss 1.091427, test error 30.10
# Epoch    14, train loss 0.013170, train error 0.00,  test loss 1.094211, test error 30.00
# Epoch    15, train loss 0.011472, train error 0.00,  test loss 1.118534, test error 30.10
# Epoch    16, train loss 0.009979, train error 0.00,  test loss 1.132712, test error 30.80
# Epoch    17, train loss 0.008880, train error 0.00,  test loss 1.148329, test error 30.20
# Epoch    18, train loss 0.008063, train error 0.00,  test loss 1.160609, test error 30.70
# Epoch    19, train loss 0.007346, train error 0.00,  test loss 1.176458, test error 30.30
# Epoch    20, train loss 0.006970, train error 0.00,  test loss 1.176021, test error 30.50
# Epoch    21, train loss 0.006689, train error 0.00,  test loss 1.181377, test error 30.60
# Epoch    22, train loss 0.006433, train error 0.00,  test loss 1.185197, test error 30.50
# Epoch    23, train loss 0.006206, train error 0.00,  test loss 1.189000, test error 30.80
# Epoch    24, train loss 0.005993, train error 0.00,  test loss 1.197015, test error 30.60
# Epoch    25, train loss 0.005787, train error 0.00,  test loss 1.198930, test error 30.70
# Epoch    26, train loss 0.005599, train error 0.00,  test loss 1.203013, test error 30.50
# Epoch    27, train loss 0.005415, train error 0.00,  test loss 1.207357, test error 30.50
# Epoch    28, train loss 0.005250, train error 0.00,  test loss 1.211357, test error 30.40
# Epoch    29, train loss 0.005095, train error 0.00,  test loss 1.215622, test error 30.40
# Epoch    30, train loss 0.005015, train error 0.00,  test loss 1.217650, test error 30.50
# Epoch    31, train loss 0.004941, train error 0.00,  test loss 1.219377, test error 30.60
# Epoch    32, train loss 0.004871, train error 0.00,  test loss 1.221465, test error 30.60
# Epoch    33, train loss 0.004803, train error 0.00,  test loss 1.223139, test error 30.60
# Epoch    34, train loss 0.004737, train error 0.00,  test loss 1.225504, test error 30.40
# Epoch    35, train loss 0.004672, train error 0.00,  test loss 1.226890, test error 30.60
# Epoch    36, train loss 0.004609, train error 0.00,  test loss 1.228324, test error 30.50
# Epoch    37, train loss 0.004548, train error 0.00,  test loss 1.229871, test error 30.40
# Epoch    38, train loss 0.004487, train error 0.00,  test loss 1.231974, test error 30.40
# Epoch    39, train loss 0.004429, train error 0.00,  test loss 1.233422, test error 30.40
# Epoch    40, train loss 0.004400, train error 0.00,  test loss 1.234338, test error 30.40
# Epoch    41, train loss 0.004372, train error 0.00,  test loss 1.235360, test error 30.40
# Epoch    42, train loss 0.004344, train error 0.00,  test loss 1.235813, test error 30.40
# Epoch    43, train loss 0.004317, train error 0.00,  test loss 1.236932, test error 30.40
# Epoch    44, train loss 0.004290, train error 0.00,  test loss 1.237737, test error 30.40
# Epoch    45, train loss 0.004263, train error 0.00,  test loss 1.238353, test error 30.40
# Epoch    46, train loss 0.004237, train error 0.00,  test loss 1.239333, test error 30.40
# Epoch    47, train loss 0.004210, train error 0.00,  test loss 1.240150, test error 30.40
# Epoch    48, train loss 0.004185, train error 0.00,  test loss 1.240974, test error 30.40
# Epoch    49, train loss 0.004159, train error 0.00,  test loss 1.241844, test error 30.50

# %%
# Plot the results
fig, ax = plt.subplots()
ax.plot(errors_train,'r-',label='train')
ax.plot(errors_test,'b-',label='test')
ax.set_ylim(0,100); ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Error')
ax.set_title('TrainError %3.2f, Test Error %3.2f'%(errors_train[-1],errors_test[-1]))
ax.legend()
plt.show()

# Plot the results
fig, ax = plt.subplots()
ax.plot(losses_train,'r-',label='train')
ax.plot(losses_test,'b-',label='test')
ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Loss')
ax.set_title('Train loss %3.2f, Test loss %3.2f'%(losses_train[-1],losses_test[-1]))
ax.legend()
plt.show()

# %% [markdown]
# **TODO**
#
# Play with the model -- try changing the number of layers, hidden units, learning rate, batch size, momentum or anything else you like.  See if you can improve the test results.
#
# Is it a good idea to optimize the hyperparameters in this way?  Will the final result be a good estimate of the true test performance?
#
# 最好的test_loss是27在調小了batch_size 調高了learning rate，和增加了一層hidden layer 再加上hidden unit調整成200
